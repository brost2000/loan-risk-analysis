# %%
import pandas as pd

data = pd.read_csv(f"/Users/alexanderbrost/Desktop/root/py/banking_data/LoanDataset - LoansDatasest.csv")

# %%
# take basic look at dataset and basic descriptive info

print(
    data.head(),
    data.tail(),
    data.info(),
    data.describe()
)

# %%
# check for null or NaN values and clean if necessary

def isnull_any(data):
    return data.isnull().any()

isnull_any(data)
# Out:
# customer_id             True
# customer_age           False
# customer_income        False
# home_ownership         False
# employment_duration     True
# loan_intent            False
# loan_grade             False
# loan_amnt               True
# loan_int_rate           True
# term_years             False
# historical_default      True
# cred_hist_length       False
# Current_loan_status     True
# dtype: bool

# %%
customer_id_null = data[data['customer_id'].isnull()]
customer_id_null

# looks like three rows missing custID
# Out:
#        customer_id  customer_age customer_income home_ownership  \
# 25559          NaN            31           83000           RENT
# 25560          NaN            30           86000       MORTGAGE
# 25561          NaN            27           74000       MORTGAGE
#
#        employment_duration        loan_intent loan_grade   loan_amnt  \
# 25559                  2.0           PERSONAL          B  £12,000.00
# 25560                  7.0  DEBTCONSOLIDATION          B  £10,000.00
# 25561                  3.0           PERSONAL          B  £25,000.00
#
#        loan_int_rate  term_years historical_default  cred_hist_length  \
# 25559          12.42           1                NaN                 7
# 25560            NaN           3                NaN                10
# 25561          11.46           7                  N                 5
#
#       Current_loan_status
# 25559          NO DEFAULT
# 25560          NO DEFAULT
# 25561             DEFAULT

# %%
employment_duration_null = data[data['employment_duration'].isnull()]
employment_duration_null

# large amount of missing employment duration
# Out:
#        customer_id  customer_age customer_income home_ownership  \
# 105          106.0            22           12600       MORTGAGE
# 222          223.0            24          185000       MORTGAGE
# 381          380.0            24           16800       MORTGAGE
# 409          408.0            25           52000           RENT
# 410          409.0            22           17352       MORTGAGE
# ...            ...           ...             ...            ...
# 32290      32286.0            38           12000            OWN
# 32333      32329.0            51           18408           RENT
# 32365      32361.0            70           39996           RENT
# 32458      32454.0            56           32400           RENT
# 32476      32472.0            53           54000           RENT
#
#        employment_duration        loan_intent loan_grade   loan_amnt  \
# 105                    NaN           PERSONAL          A   £2,000.00
# ...
